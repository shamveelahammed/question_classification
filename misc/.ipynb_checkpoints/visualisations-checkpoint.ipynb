# %%
import numpy as np
import matplotlib.pyplot as plt
import random

epoch = range(1,11)

# %%
BOW_val_losses = random.sample(range(10, 30), 10)

# %%
BOW_train_losses = random.sample(range(10, 30), 10)

# %%
BiLSTM_val_losses = random.sample(range(10, 30), 10)

# %%
BiLSTM_train_losses = random.sample(range(10, 30), 10)

# %%
plt.figure(figsize=(8,6))
plt.plot(losses)
plt.plot(epoch, BOW_val_losses, 'b-', label='Bow validation') 
plt.plot(epoch, BiLSTM_val_losses, 'r-', label='BiLSTM validation')

plt.plot(epoch, BOW_train_losses, 'b--', label='Bow train') 
plt.plot(epoch, BiLSTM_train_losses, 'r--', label='BiLSTM train')

plt.legend()

plt.ylabel('1-Loss')
plt.show()
